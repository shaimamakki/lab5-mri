# %%
spark.conf.set(
    ="
)

# %%
# If scikit-image is not installed, uncomment and run once:
#%pip install scikit-image

import time
import numpy as np
import pandas as pd

from pyspark.sql import Row
import pyspark.sql.functions as F

from skimage import io
from skimage.filters import gaussian, sobel, prewitt, hessian
from skimage.filters.rank import entropy as entropy_filter
from skimage.morphology import disk
from skimage.filters import gabor

# Correct NEW names (skimage >= 0.20)
from skimage.feature import graycomatrix, graycoprops

# %%
bronze_path = "abfss://lakehouse@lab5mri.dfs.core.windows.net/bronze/tumor_images_raw/"

bronze_df = (
    spark.read.parquet(bronze_path)
    .select("image_id", "label", "image_path")
)

bronze_df.show(5)
rows = bronze_df.collect()
print(f"Total images found in Bronze: {len(rows)}")
# Out:
# +----------+-----+--------------------+
# |  image_id|label|          image_path|
# +----------+-----+--------------------+
# | 34 no.jpg|    0|abfss://lakehouse...|
# |no 100.jpg|    0|abfss://lakehouse...|
# | 30 no.jpg|    0|abfss://lakehouse...|
# | 23 no.jpg|    0|abfss://lakehouse...|
# | 38 no.jpg|    0|abfss://lakehouse...|
# +----------+-----+--------------------+
# only showing top 5 rows
# Total images found in Bronze: 253

# %%
from skimage.feature import graycomatrix, graycoprops

ANGLES = [0, np.pi/4, np.pi/2, 3*np.pi/4]
DISTANCES = [1]
GLCM_PROPS = ["contrast", "dissimilarity", "homogeneity", "ASM", "energy", "correlation"]

def compute_glcm_features(image, prefix):
    """
    Computes GLCM properties for a given image (2D array) using multiple angles.
    Returns a dictionary of mean & std for each property.
    """
    arr = np.asarray(image, dtype=np.float32)

    # normalize 0-1
    arr = arr - arr.min()
    if arr.max() > 0:
        arr = arr / arr.max()

    # convert back to uint8
    arr_uint8 = (arr * 255).astype(np.uint8)

    # compute GLCM
    glcm = graycomatrix(
        arr_uint8,
        distances=DISTANCES,
        angles=ANGLES,
        levels=256,
        symmetric=True,
        normed=True
    )

    feats = {}
    for prop in GLCM_PROPS:
        vals = graycoprops(glcm, prop)[0]  # one value per angle
        feats[f"{prefix}_{prop}_mean"] = float(vals.mean())
        feats[f"{prefix}_{prop}_std"] = float(vals.std())
    return feats

# %%
from io import BytesIO
import imageio

def process_one_row(row):
    image_id = row["image_id"]
    label = row["label"]
    path = row["image_path"]

    try:
        # Load image bytes via Spark
        img_bytes = (
            spark.read.format("binaryFile")
            .load(path)
            .select("content")
            .first()
            .content
        )

        # Convert bytes -> BytesIO -> grayscale float image
        img = imageio.v2.imread(BytesIO(img_bytes), mode='F')  # ← FIXED

        # Normalize for safety (0–1)
        img = img.astype(np.float32)
        img = (img - img.min()) / (img.max() - img.min() + 1e-8)

        # ---- filters ----
        ent = entropy_filter((img * 255).astype(np.uint8), disk(3))
        gauss = gaussian(img, sigma=1)
        sob = sobel(img)
        prew = prewitt(img)
        hess = hessian(img, mode="reflect")
        gabor_real, _ = gabor(img, frequency=0.2)

        # ---- GLCM features ----
        features = {
            "image_id": image_id,
            "label": int(label)
        }

        features.update(compute_glcm_features(img, "orig"))
        features.update(compute_glcm_features(ent, "entropy"))
        features.update(compute_glcm_features(gauss, "gaussian"))
        features.update(compute_glcm_features(sob, "sobel"))
        features.update(compute_glcm_features(prew, "prewitt"))
        features.update(compute_glcm_features(hess, "hessian"))
        features.update(compute_glcm_features(gabor_real, "gabor"))

        return features

    except Exception as e:
        print(f"❌ ERROR processing {image_id}")
        print(f"Reason: {e}")
        return None

# %%
import time

start_time = time.time()

results = []

print("Starting safe feature extraction...\n")

for i, row in enumerate(rows):
    print(f"Processing image {i+1}/{len(rows)}: {row['image_id']}")
    feat = process_one_row(row)
    if feat is not None:
        results.append(feat)

end_time = time.time()
extraction_time_seconds = end_time - start_time

print("\n====================")
print("SAFE EXTRACTION DONE")
print("====================")
print(f"Images processed successfully: {len(results)}")
print(f"Total extraction time: {extraction_time_seconds:.2f} seconds")
# Out:
# Starting safe feature extraction...
#
# Processing image 1/253: 34 no.jpg
# Processing image 2/253: no 100.jpg
# Processing image 3/253: 30 no.jpg
# Processing image 4/253: 23 no.jpg
# Processing image 5/253: 38 no.jpg
# Processing image 6/253: 8 no.jpg
# Processing image 7/253: 22 no.jpg
# Processing image 8/253: 31 no.jpg
# Processing image 9/253: 39 no.jpg
# Processing image 10/253: 15 no.jpg
# Processing image 11/253: 35 no.jpg
# Processing image 12/253: 32 no.jpg
# Processing image 13/253: 18 no.jpg
# Processing image 14/253: 19 no.jpg
# Processing image 15/253: 40 no.jpg
# Processing image 16/253: 41 no.jpg
# Processing image 17/253: 42 no.jpg
# Processing image 18/253: 47 no.jpg
# Processing image 19/253: 28 no.jpg
# Processing image 20/253: 14 no.jpg
# Processing image 21/253: no 1.jpg
# Processing image 22/253: no 923.jpg
# Processing image 23/253: no 6.jpg
# Processing image 24/253: 25 no.jpg
# Processing image 25/253: 5 no.jpg
# Processing image 26/253: 29 no.jpg
# Processing image 27/253: 45 no.jpg
# Processing image 28/253: N19.JPG
# Processing image 29/253: no 2.jpg
# Processing image 30/253: 49 no.jpg
# Processing image 31/253: Y252.jpg
# Processing image 32/253: Y81.jpg
# Processing image 33/253: Y167.JPG
# Processing image 34/253: Y92.png
# Processing image 35/253: Y194.jpg
# Processing image 36/253: Y26.jpg
# Processing image 37/253: Y249.JPG
# Processing image 38/253: Y12.jpg
# Processing image 39/253: Y147.JPG
# Processing image 40/253: Y47.JPG
# Processing image 41/253: Y161.JPG
# Processing image 42/253: Y258.JPG
# Processing image 43/253: Y251.JPG
# Processing image 44/253: Y159.JPG
# Processing image 45/253: Y195.JPG
# Processing image 46/253: Y45.JPG
# Processing image 47/253: Y247.JPG
# Processing image 48/253: Y86.JPG
# Processing image 49/253: Y256.JPG
# Processing image 50/253: Y58.JPG
# Processing image 51/253: Y154.jpg
# Processing image 52/253: Y79.jpg
# Processing image 53/253: Y253.JPG
# Processing image 54/253: Y11.jpg
# Processing image 55/253: Y181.jpg
# Processing image 56/253: Y34.jpg
# Processing image 57/253: Y187.jpg
# Processing image 58/253: Y250.jpg
# Processing image 59/253: Y245.jpg
# Processing image 60/253: Y95.jpg
# Processing image 61/253: Y156.JPG
# Processing image 62/253: Y183.jpg
# Processing image 63/253: Y153.jpg
# Processing image 64/253: Y14.jpg
# Processing image 65/253: Y192.JPG
# Processing image 66/253: Y16.JPG
# Processing image 67/253: Y112.JPG
# Processing image 68/253: Y146.JPG
# Processing image 69/253: Y100.JPG
# Processing image 70/253: Y19.JPG
# Processing image 71/253: Y116.JPG
# Processing image 72/253: Y98.JPG
# Processing image 73/253: Y182.JPG
# Processing image 74/253: Y255.JPG
# Processing image 75/253: Y114.JPG
# Processing image 76/253: Y184.JPG
# Processing image 77/253: Y246.JPG
# Processing image 78/253: Y158.JPG
# Processing image 79/253: No20.jpg
# Processing image 80/253: no 8.jpg
# Processing image 81/253: 9 no.jpg
# Processing image 82/253: 6 no.jpg
# Processing image 83/253: no 90.jpg
# Processing image 84/253: N3.jpg
# Processing image 85/253: Y51.jpg
# Processing image 86/253: Y104.jpg
# Processing image 87/253: Y90.jpg
# Processing image 88/253: Y107.jpg
# Processing image 89/253: Y96.jpg
# Processing image 90/253: Y188.jpg
# Processing image 91/253: Y52.jpg
# Processing image 92/253: Y180.jpg
# Processing image 93/253: Y29.jpg
# Processing image 94/253: Y111.JPG
# Processing image 95/253: Y50.JPG
# Processing image 96/253: Y115.JPG
# Processing image 97/253: Y89.JPG
# Processing image 98/253: Y259.JPG
# Processing image 99/253: Y23.JPG
# Processing image 100/253: Y164.JPG
# Processing image 101/253: Y59.JPG
# Processing image 102/253: Y165.JPG
# Processing image 103/253: Y101.jpg
# Processing image 104/253: Y9.jpg
# Processing image 105/253: Y3.jpg
# Processing image 106/253: Y102.jpg
# Processing image 107/253: Y7.jpg
# Processing image 108/253: Y248.JPG
# Processing image 109/253: Y24.jpg
# Processing image 110/253: Y41.jpg
# Processing image 111/253: Y55.jpg
# Processing image 112/253: Y74.jpg
# Processing image 113/253: Y20.jpg
# Processing image 114/253: Y71.JPG
# Processing image 115/253: Y76.jpg
# Processing image 116/253: Y66.JPG
# Processing image 117/253: Y78.jpg
# Processing image 118/253: Y56.jpg
# Processing image 119/253: Y82.jpg
# Processing image 120/253: Y53.jpg
# Processing image 121/253: Y46.jpg
# Processing image 122/253: Y73.jpg
# Processing image 123/253: Y62.jpg
# Processing image 124/253: Y10.jpg
# Processing image 125/253: 4 no.jpg
# Processing image 126/253: N5.jpg
# Processing image 127/253: Y2.jpg
# Processing image 128/253: Y42.jpg
# Processing image 129/253: Y92.jpg
# Processing image 130/253: Y1.jpg
# Processing image 131/253: Y35.jpg
# Processing image 132/253: Y8.jpg
# Processing image 133/253: no 91.jpeg
# Processing image 134/253: 48 no.jpeg
# Processing image 135/253: no 7.jpeg
# Processing image 136/253: 46 no.jpg
# Processing image 137/253: 1 no.jpeg
# Processing image 138/253: no 95.jpg
# Processing image 139/253: no 89.jpg
# Processing image 140/253: 11 no.jpg
# Processing image 141/253: no 96.jpg
# Processing image 142/253: Y254.jpg
# Processing image 143/253: No11.jpg
# Processing image 144/253: 7 no.jpg
# Processing image 145/253: No12.jpg
# Processing image 146/253: No19.jpg
# Processing image 147/253: N21.jpg
# Processing image 148/253: N17.jpg
# Processing image 149/253: 26 no.jpg
# Processing image 150/253: No16.jpg
# Processing image 151/253: 21 no.jpg
# Processing image 152/253: 43 no.jpg
# Processing image 153/253: 17 no.jpg
# Processing image 154/253: 27 no.jpg
# Processing image 155/253: no 92.jpg
# Processing image 156/253: 13 no.jpg
# Processing image 157/253: 33 no.jpg
# Processing image 158/253: 36 no.jpg
# Processing image 159/253: 12 no.jpg
# Processing image 160/253: 10 no.jpg
# Processing image 161/253: no 5.jpeg
# Processing image 162/253: no 97.jpg
# Processing image 163/253: no 3.jpg
# Processing image 164/253: 50 no.jpg
# Processing image 165/253: 3 no.jpg
# Processing image 166/253: 24 no.jpg
# Processing image 167/253: 37 no.jpg
# Processing image 168/253: N16.jpg
# Processing image 169/253: Y160.JPG
# Processing image 170/253: Y242.JPG
# Processing image 171/253: Y163.JPG
# Processing image 172/253: Y49.JPG
# Processing image 173/253: Y166.JPG
# Processing image 174/253: Y67.JPG
# Processing image 175/253: Y168.jpg
# Processing image 176/253: Y31.jpg
# Processing image 177/253: Y108.jpg
# Processing image 178/253: Y162.jpg
# Processing image 179/253: Y257.jpg
# Processing image 180/253: Y61.jpg
# Processing image 181/253: Y155.JPG
# Processing image 182/253: Y170.JPG
# Processing image 183/253: Y244.JPG
# Processing image 184/253: Y193.JPG
# Processing image 185/253: Y117.JPG
# Processing image 186/253: Y186.jpg
# Processing image 187/253: Y113.JPG
# Processing image 188/253: Y243.JPG
# Processing image 189/253: Y120.JPG
# Processing image 190/253: Y22.jpg
# Processing image 191/253: Y157.JPG
# Processing image 192/253: Y15.jpg
# Processing image 193/253: Y91.jpg
# Processing image 194/253: Y103.jpg
# Processing image 195/253: Y75.JPG
# Processing image 196/253: Y109.JPG
# Processing image 197/253: Y97.JPG
# Processing image 198/253: Y185.jpg
# Processing image 199/253: Y60.jpg
# Processing image 200/253: Y105.jpg
# Processing image 201/253: Y99.JPG
# Processing image 202/253: Y148.JPG
# Processing image 203/253: Y13.jpg
# Processing image 204/253: Y169.jpg
# Processing image 205/253: N6.jpg
# Processing image 206/253: 20 no.jpg
# Processing image 207/253: N22.JPG
# Processing image 208/253: 44no.jpg
# Processing image 209/253: no 4.jpg
# Processing image 210/253: N15.jpg
# Processing image 211/253: Y4.jpg
# Processing image 212/253: Y106.jpg
# Processing image 213/253: Y25.jpg
# Processing image 214/253: Y69.jpg
# Processing image 215/253: Y17.jpg
# Processing image 216/253: Y32.jpg
# Processing image 217/253: Y18.JPG
# Processing image 218/253: Y85.JPG
# Processing image 219/253: Y65.JPG
# Processing image 220/253: Y36.JPG
# Processing image 221/253: Y54.jpg
# Processing image 222/253: Y70.jpg
# Processing image 223/253: Y39.jpg
# Processing image 224/253: Y77.jpg
# Processing image 225/253: Y37.jpg
# Processing image 226/253: Y21.jpg
# Processing image 227/253: N1.JPG
# Processing image 228/253: No13.jpg
# Processing image 229/253: N2.JPG
# Processing image 230/253: No14.jpg
# Processing image 231/253: Y28.jpg
# Processing image 232/253: Y27.jpg
# Processing image 233/253: Y44.JPG
# Processing image 234/253: Y40.JPG
# Processing image 235/253: Y30.jpg
# Processing image 236/253: Y38.jpg
# Processing image 237/253: N26.JPG
# Processing image 238/253: N20.JPG
# Processing image 239/253: Y33.jpg
# Processing image 240/253: Y6.jpg
# Processing image 241/253: no 98.jpg
# Processing image 242/253: 2 no.jpeg
# Processing image 243/253: no 94.jpg
# Processing image 244/253: no 10.jpg
# Processing image 245/253: no 99.jpg
# Processing image 246/253: no 9.png
# Processing image 247/253: No18.jpg
# Processing image 248/253: No15.jpg
# Processing image 249/253: No17.jpg
# Processing image 250/253: No22.jpg
# Processing image 251/253: No21.jpg
# Processing image 252/253: N11.jpg
# Processing image 253/253: no.jpg
#
# ====================
# SAFE EXTRACTION DONE
# ====================
# Images processed successfully: 253
# Total extraction time: 662.26 seconds

# %%
# Convert results to pandas DF
import pandas as pd

silver_pdf = pd.DataFrame(results)
print("Silver dataframe shape:", silver_pdf.shape)

# Convert to Spark DataFrame
silver_df = spark.createDataFrame(silver_pdf)

# Save path
silver_path = "abfss://lakehouse@lab5mri.dfs.core.windows.net/silver/tumor_features/"

silver_df.write.mode("overwrite").parquet(silver_path)

print("Silver layer saved to:", silver_path)
# Out:
# Silver dataframe shape: (253, 86)
# Silver layer saved to: abfss://lakehouse@lab5mri.dfs.core.windows.net/silver/tumor_features/

# %%
num_images = len(results)
num_features = len(silver_df.columns) - 2   # minus image_id + label

print("=== METRICS ===")
print("Images:", num_images)
print("Features per image:", num_features)
print("Total extraction time (sec):", extraction_time_seconds)

# Detect compute SKU
import os
compute_sku = os.environ.get("AZUREML_COMPUTE", "databricks_cluster")
print("Compute SKU:", compute_sku)
# Out:
# === METRICS ===
# Images: 253
# Features per image: 84
# Total extraction time (sec): 662.25750041008
# Compute SKU: databricks_cluster
